# %%
import string, re
from unicodedata import normalize
from numpy.random import shuffle
from numpy import argmax
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu
from pickle import load, dump
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding, RepeatVector, TimeDistributed
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Dataset

# %%
# load doc into memory
def load_doc(filename):
    file = open(filename, mode='rt', encoding='utf-8')
    text = file.read()
    file.close()
    return text

# %%
filename = '/content/drive/My Drive/Bangla English Translation/ben.txt'
doc = load_doc(filename)

# %%
doc
# Out:
# 'Go.\tযাও।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #5545004 (tanay)\nGo.\tযান।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #5545005 (tanay)\nGo.\tযা।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #5545006 (tanay)\nRun!\tপালাও!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #5548781 (tanay)\nRun!\tপালান!\tCC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #5548783 (tanay)\nWho?\tকে?\tCC-BY 2.0 (France) Attribution: tatoeba.org #2083030 (CK) & #5548787 (tanay)\nFire!\tআগুন!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #3232240 (tanay)\nHelp!\tবাঁচাও!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #5548780 (tanay)\nHelp!\tবাঁচান!\tCC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #5548782 (tanay)\nStop!\tথামুন!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #5545000 (tanay)\nStop!\tথামো!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #5545001 (tanay)\nStop!\tথাম!\tCC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #5545002 (tanay)\nHello!\tনমস্কার!\tCC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #3042686 (tanay)\nI see.\tবুঝলাম।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2111796 (CK) & #3220326 (tanay)\nI try.\tআমি চেষ্টা করি।\tCC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #3219704 (tanay)\nSmile.\tএকটু হাসুন।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #3232180 (tanay)\nSmile.\tএকটু হাসো।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #3232182 (tanay)\nAttack!\tআক্রমণ!\tCC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #5489253 (tanay)\nGet up.\tওঠো।\tCC-BY 2.0 (France) Attribution: tatoeba.org #896158 (pauldhunt) & #3235044 (tanay)\nGet up.\tউঠুন।\tCC-BY 2.0 (France) Attribution: tatoeba.org #896158 (pauldhunt) & #3235045 (tanay)\nGot it!\tবুঝে গেছি!\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5530042 (tanay)\nGot it!\tধরেছি!\tCC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #5530043 (tanay)\nGot it?\tবুঝেছো?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #5545028 (tanay)\nGot it?\tবুঝেছেন?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #5545029 (tanay)\nGot it?\tবুঝেছিস?\tCC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #5545030 (tanay)\nI know.\tআমি জানি।\tCC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #3220322 (tanay)\nI know.\tআমার জানা আছে।\tCC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #3220324 (tanay)\nI lost.\tআমি হেরে গেছি।\tCC-BY 2.0 (France) Attribution: tatoeba.org #1755073 (Eldad) & #3220391 (tanay)\nI\'m 19.\tআমার ১৯ বছর বয়স।\tCC-BY 2.0 (France) Attribution: tatoeba.org #442400 (sacredceltic) & #3220383 (tanay)\nI\'m OK.\tআমি ঠিক আছি।\tCC-BY 2.0 (France) Attribution: tatoeba.org #433763 (CK) & #3220355 (tanay)\nListen.\tশোন।\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #5548784 (tanay)\nListen.\tশুনুন।\tCC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #5548785 (tanay)\nNo way!\tকোন মতেই না!\tCC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #5548797 (tanay)\nReally?\tসত্যি?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #3219710 (tanay)\nReally?\tতাই নাক?\tCC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #3219713 (tanay)\nThanks.\tধন্যবাদ।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #3220431 (tanay)\nTry it.\tচেখে দেখুন।\tCC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #5545554 (tanay)\nTry it.\tচেখে দেখো।\tCC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #5545555 (tanay)\nWe won.\tআমরা জিতে গেছে।\tCC-BY 2.0 (France) Attribution: tatoeba.org #2107675 (CK) & #3219996 (tanay)\nWhy me?\tআমিই কেন?\tCC-BY 2.0 (France) Attribution: tatoeba.org #24958 (CK) & #3219958 (tanay)\nAsk Tom.\tটমকে জিজ্ঞাসা করো।\tCC-BY 2.0 (Franc ...

# %% [markdown]
# ## Document into Sentence

# %%
def to_pairs(doc):
    lines = doc.strip().split('\n')
    pairs = [line.split('\t') for line in lines]
    return pairs

# %%
pairs = to_pairs(doc)

# %%
#printing five list
for i in range(5):
  print(pairs[i])
# Out:
# ['Go.', 'যাও।', 'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #5545004 (tanay)']
# ['Go.', 'যান।', 'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #5545005 (tanay)']
# ['Go.', 'যা।', 'CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #5545006 (tanay)']
# ['Run!', 'পালাও!', 'CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #5548781 (tanay)']
# ['Run!', 'পালান!', 'CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #5548783 (tanay)']

# %%
print('Length of the dataset is :', len(pairs))
# Out:
# Length of the dataset is : 4349

# %% [markdown]
# ## Clean Dataset

# %%
# clean a list of lines
def clean_pairs(lines):
    cleaned = list()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    
    for pair in lines:
        clean_pair = list()
        for line in pair:
            
            # normalize unicode characters
            #line = normalize('NFD', line).encode('ascii', 'ignore')
            #line = line.decode('UTF-8')
            line = line.split()
            
            # remove punctuation from each token
            line = [re_punc.sub('', w) for w in line]

            #line = line.replace('?','')
            line = [item.replace("?", "") for item in line]
            #line = line.replace('।','')
            line = [item.replace("।", "") for item in line]
            #line = line.replace('!','')
            line = [item.replace("!", "") for item in line]
            
            
            
            clean_pair.append(' '.join(line))
        cleaned.append(clean_pair)
    return np.array(cleaned)

# %%
clean_pairs = clean_pairs(pairs)

# %%
#clean data
clean_pairs
# Out:
# array([['Go', 'যাও',
#         'CCBY 20 France Attribution tatoebaorg 2877272 CM  5545004 tanay'],
#        ['Go', 'যান',
#         'CCBY 20 France Attribution tatoebaorg 2877272 CM  5545005 tanay'],
#        ['Go', 'যা',
#         'CCBY 20 France Attribution tatoebaorg 2877272 CM  5545006 tanay'],
#        ...,
#        ['Tom told Mary that he was going to kill himself but he didnt have the courage to do it',
#         'টম মেরিকে বললো যে ও নিজেকে হত্যা করতে চলেছিলো কিন্ত তা করার মতো সাহস ছিলো না',
#         'CCBY 20 France Attribution tatoebaorg 1027913 CK  5692504 tanay'],
#        ['Toms an irritating person to work with because hell never admit it when hes made a mistake',
#         'টমের সঙ্গে কাজ করা খুব বিরক্তিকর কারণ ও কখনই মেনে নেয় না যে ও ভুল করেছে',
#         'CCBY 20 France Attribution tatoebaorg 1023866 CK  5692494 tanay'],
#        ['I thought doing this would be easy but weve been working all day and were still not finished',
#         'আমি ভেবেছিলাম এটা করা সহজ হবে কিন্তু আমরা সারাদিন ধরে কাজ করেছি আর এখনো শেষ করে উঠতে পারিনি',
#         'CCBY 20 France Attribution tatoebaorg 953658 CK  5692486 tanay']],
#       dtype='<U92')

# %% [markdown]
# ## Saving Clean data

# %%
def save_clean_data(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
save_clean_data(clean_pairs, 'english-bangla.pkl')
# Out:
# Saved: english-bangla.pkl

# %% [markdown]
# ## Printing Some Pair of Word

# %%
for i in range(100):
    print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# [Go] => [যাও]
# [Go] => [যান]
# [Go] => [যা]
# [Run] => [পালাও]
# [Run] => [পালান]
# [Who] => [কে]
# [Fire] => [আগুন]
# [Help] => [বাঁচাও]
# [Help] => [বাঁচান]
# [Stop] => [থামুন]
# [Stop] => [থামো]
# [Stop] => [থাম]
# [Hello] => [নমস্কার]
# [I see] => [বুঝলাম]
# [I try] => [আমি চেষ্টা করি]
# [Smile] => [একটু হাসুন]
# [Smile] => [একটু হাসো]
# [Attack] => [আক্রমণ]
# [Get up] => [ওঠো]
# [Get up] => [উঠুন]
# [Got it] => [বুঝে গেছি]
# [Got it] => [ধরেছি]
# [Got it] => [বুঝেছো]
# [Got it] => [বুঝেছেন]
# [Got it] => [বুঝেছিস]
# [I know] => [আমি জানি]
# [I know] => [আমার জানা আছে]
# [I lost] => [আমি হেরে গেছি]
# [Im 19] => [আমার ১৯ বছর বয়স]
# [Im OK] => [আমি ঠিক আছি]
# [Listen] => [শোন]
# [Listen] => [শুনুন]
# [No way] => [কোন মতেই না]
# [Really] => [সত্যি]
# [Really] => [তাই নাক]
# [Thanks] => [ধন্যবাদ]
# [Try it] => [চেখে দেখুন]
# [Try it] => [চেখে দেখো]
# [We won] => [আমরা জিতে গেছে]
# [Why me] => [আমিই কেন]
# [Ask Tom] => [টমকে জিজ্ঞাসা করো]
# [Ask Tom] => [টমকে জিজ্ঞাসা করুন]
# [Ask Tom] => [টমকে জিজ্ঞাসা কর]
# [Call me] => [আমাকে ডেক]
# [Call me] => [আমাকে ডাকবেন]
# [Call me] => [আমাকে ডাকিস]
# [Call us] => [আমাদের ডেকো]
# [Call us] => [আমাদের ডাকিস]
# [Call us] => [আমাদের ডাকবেন]
# [Come in] => [ভেতরে আসুন]
# [Come in] => [ভেতরে আসো]
# [Get Tom] => [টমকে আনো]
# [Get Tom] => [টমকে ডাকো]
# [Get Tom] => [টমকে ধরো]
# [Get Tom] => [টমকে আনুন]
# [Get Tom] => [টমকে ডাকুন]
# [Get Tom] => [টমকে ধরুন]
# [Get out] => [বেরও]
# [Get out] => [বেরো]
# [Go away] => [চলে যাও]
# [Go away] => [চলে যান]
# [Go away] => [চলে যাও]
# [Go away] => [চলে যান]
# [Go home] => [বাড়ি যাও]
# [Go home] => [বাড়ি যা]
# [Go home] => [বাড়ি যান]
# [Go slow] => [আস্তে যান]
# [Go slow] => [আস্তে যাও]
# [Go slow] => [আস্তে যা]
# [Goodbye] => [বিদায়]
# [Goodbye] => [এলাম]
# [He came] => [সে এসেছিলো]
# [He came] => [উনি এসেছিলেন]
# [He came] => [ও এসেছিলো]
# [He came] => [তিনি এসেছিলেন]
# [He runs] => [এ দৌড়ায়]
# [He runs] => [ইনি দৌড়ান]
# [He runs] => [ও দৌড়ায়]
# [He runs] => [সে দৌড়ায়]
# [He runs] => [উনি দৌড়ান]
# [He runs] => [তিনি দৌড়ান]
# [Help me] => [আমাকে সাহায্য করুন]
# [Help us] => [আমাদের সাহায্য করুন]
# [Help us] => [আমাদের সাহায্য করো]
# [Help us] => [আমাদের সাহায্য কর]
# [Hit Tom] => [টমকে মারো]
# [Hit Tom] => [টমকে মার]
# [Hit Tom] => [টমকে মারুন]
# [I agree] => [আমি একমত]
# [I tried] => [আমি চেষ্টা করেছিলাম]
# [I tried] => [আমি চেষ্টা করেছি]
# [Im Tom] => [আমি টম]
# [Im shy] => [আমি লাজুক]
# [Im wet] => [আমি ভিজে গেছি]
# [Its me] => [আমি]
# [Keep it] => [ওটা রাখো]
# [Keep it] => [ওটা রাখুন]
# [Keep it] => [ওটা রাখ]
# [Me too] => [আমিও]
# [Perfect] => [একদম ঠিক]

# %% [markdown]
# ## Loading Dataset

# %%
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))

# %%
raw_dataset = load_clean_sentences('english-bangla.pkl')

# %%
#loaded data
raw_dataset
# Out:
# array([['Go', 'যাও',
#         'CCBY 20 France Attribution tatoebaorg 2877272 CM  5545004 tanay'],
#        ['Go', 'যান',
#         'CCBY 20 France Attribution tatoebaorg 2877272 CM  5545005 tanay'],
#        ['Go', 'যা',
#         'CCBY 20 France Attribution tatoebaorg 2877272 CM  5545006 tanay'],
#        ...,
#        ['Tom told Mary that he was going to kill himself but he didnt have the courage to do it',
#         'টম মেরিকে বললো যে ও নিজেকে হত্যা করতে চলেছিলো কিন্ত তা করার মতো সাহস ছিলো না',
#         'CCBY 20 France Attribution tatoebaorg 1027913 CK  5692504 tanay'],
#        ['Toms an irritating person to work with because hell never admit it when hes made a mistake',
#         'টমের সঙ্গে কাজ করা খুব বিরক্তিকর কারণ ও কখনই মেনে নেয় না যে ও ভুল করেছে',
#         'CCBY 20 France Attribution tatoebaorg 1023866 CK  5692494 tanay'],
#        ['I thought doing this would be easy but weve been working all day and were still not finished',
#         'আমি ভেবেছিলাম এটা করা সহজ হবে কিন্তু আমরা সারাদিন ধরে কাজ করেছি আর এখনো শেষ করে উঠতে পারিনি',
#         'CCBY 20 France Attribution tatoebaorg 953658 CK  5692486 tanay']],
#       dtype='<U92')

# %% [markdown]
# ## Dividing Dataset

# %%
#name change
dataset = raw_dataset

# random shuffle
shuffle(dataset)

# split into train/test
train, test = dataset[:4000], dataset[4000:]

# %% [markdown]
# ## Saving Divided dataset

# %%
def save_clean_data(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
# save
save_clean_data(dataset, 'english-bangla-both.pkl')
save_clean_data(train, 'english-bangla-train.pkl')
save_clean_data(test, 'english-bangla-test.pkl')
# Out:
# Saved: english-bangla-both.pkl
# Saved: english-bangla-train.pkl
# Saved: english-bangla-test.pkl

# %% [markdown]
# ## Loading Divided dataset

# %%
def load_clean_sentences(filename):
    return load(open(filename, 'rb'))

# %%
# load datasets
dataset = load_clean_sentences('english-bangla-both.pkl')
train = load_clean_sentences('english-bangla-train.pkl')
test = load_clean_sentences('english-bangla-test.pkl')

# %% [markdown]
# ## Tokenizer

# %%
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %% [markdown]
# ## Maximum sentence Length

# %%
# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)

# %% [markdown]
# ## English and Bangla Tokenizer

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))

# prepare Bangla tokenizer
bang_tokenizer = create_tokenizer(dataset[:, 1])
bang_vocab_size = len(bang_tokenizer.word_index) + 1
bang_length = max_length(dataset[:, 1])
print('Bangla Vocabulary Size: %d' % bang_vocab_size)
print('Bangla Max Length: %d' % (bang_length))
# Out:
# English Vocabulary Size: 1876
# English Max Length: 19
# Bangla Vocabulary Size: 2951
# Bangla Max Length: 18

# %% [markdown]
# ## Encoding and pad Sequence

# %%
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# %% [markdown]
# ## One-hot-encoding

# %%
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = np.array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# %%
# prepare training data
trainX = encode_sequences(bang_tokenizer, bang_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)

# prepare validation data
testX = encode_sequences(bang_tokenizer, bang_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# %% [markdown]
# ## Model

# %%
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    
    # compile model
    model.compile(optimizer='adam', 
                  loss='categorical_crossentropy')
    
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
# define model
model = define_model(bang_vocab_size, eng_vocab_size, bang_length, eng_length, 256)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 18, 256)           755456
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 19, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 19, 256)           525312
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 19, 1876)          482132
# =================================================================
# Total params: 2,288,212
# Trainable params: 2,288,212
# Non-trainable params: 0
# _________________________________________________________________

# %%
#checkpoint
checkpoint = ModelCheckpoint('model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
# fit model
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 4000 samples, validate on 349 samples
# Epoch 1/100
#  - 27s - loss: 2.9079 - val_loss: 1.7638
#
# Epoch 00001: val_loss improved from inf to 1.76384, saving model to model.h5
# Epoch 2/100
#  - 26s - loss: 1.6930 - val_loss: 1.5584
#
# Epoch 00002: val_loss improved from 1.76384 to 1.55840, saving model to model.h5
# Epoch 3/100
#  - 26s - loss: 1.5593 - val_loss: 1.5171
#
# Epoch 00003: val_loss improved from 1.55840 to 1.51709, saving model to model.h5
# Epoch 4/100
#  - 26s - loss: 1.4912 - val_loss: 1.4625
#
# Epoch 00004: val_loss improved from 1.51709 to 1.46248, saving model to model.h5
# Epoch 5/100
#  - 26s - loss: 1.4592 - val_loss: 1.4387
#
# Epoch 00005: val_loss improved from 1.46248 to 1.43869, saving model to model.h5
# Epoch 6/100
#  - 26s - loss: 1.4152 - val_loss: 1.4332
#
# Epoch 00006: val_loss improved from 1.43869 to 1.43325, saving model to model.h5
# Epoch 7/100
#  - 26s - loss: 1.3912 - val_loss: 1.4166
#
# Epoch 00007: val_loss improved from 1.43325 to 1.41660, saving model to model.h5
# Epoch 8/100
#  - 25s - loss: 1.3578 - val_loss: 1.4082
#
# Epoch 00008: val_loss improved from 1.41660 to 1.40824, saving model to model.h5
# Epoch 9/100
#  - 25s - loss: 1.3385 - val_loss: 1.3978
#
# Epoch 00009: val_loss improved from 1.40824 to 1.39782, saving model to model.h5
# Epoch 10/100
#  - 25s - loss: 1.3263 - val_loss: 1.3932
#
# Epoch 00010: val_loss improved from 1.39782 to 1.39325, saving model to model.h5
# Epoch 11/100
#  - 26s - loss: 1.3095 - val_loss: 1.3901
#
# Epoch 00011: val_loss improved from 1.39325 to 1.39014, saving model to model.h5
# Epoch 12/100
#  - 26s - loss: 1.2958 - val_loss: 1.3943
#
# Epoch 00012: val_loss did not improve from 1.39014
# Epoch 13/100
#  - 25s - loss: 1.2864 - val_loss: 1.3812
#
# Epoch 00013: val_loss improved from 1.39014 to 1.38120, saving model to model.h5
# Epoch 14/100
#  - 26s - loss: 1.2755 - val_loss: 1.3800
#
# Epoch 00014: val_loss improved from 1.38120 to 1.37997, saving model to model.h5
# Epoch 15/100
#  - 25s - loss: 1.2581 - val_loss: 1.3780
#
# Epoch 00015: val_loss improved from 1.37997 to 1.37805, saving model to model.h5
# Epoch 16/100
#  - 25s - loss: 1.2440 - val_loss: 1.3694
#
# Epoch 00016: val_loss improved from 1.37805 to 1.36943, saving model to model.h5
# Epoch 17/100
#  - 25s - loss: 1.2315 - val_loss: 1.3600
#
# Epoch 00017: val_loss improved from 1.36943 to 1.36001, saving model to model.h5
# Epoch 18/100
#  - 25s - loss: 1.2128 - val_loss: 1.3516
#
# Epoch 00018: val_loss improved from 1.36001 to 1.35157, saving model to model.h5
# Epoch 19/100
#  - 25s - loss: 1.1949 - val_loss: 1.3301
#
# Epoch 00019: val_loss improved from 1.35157 to 1.33009, saving model to model.h5
# Epoch 20/100
#  - 25s - loss: 1.1705 - val_loss: 1.3223
#
# Epoch 00020: val_loss improved from 1.33009 to 1.32232, saving model to model.h5
# Epoch 21/100
#  - 25s - loss: 1.1484 - val_loss: 1.3159
#
# Epoch 00021: val_loss improved from 1.32232 to 1.31594, saving model to model.h5
# Epoch 22/100
#  - 25s - loss: 1.1225 - val_loss: 1.2990
#
# Epoch 00022: val_loss improved from 1.31594 to 1.29904, saving model to model.h5
# Epoch 23/100
#  - 25s - loss: 1.0975 - val_loss: 1.2862
#
# Epoch 00023: val_loss improved from 1.29904 to 1.28617, saving model to model.h5
# Epoch 24/100
#  - 26s - loss: 1.0757 - val_loss: 1.2727
#
# Epoch 00024: val_loss improved from 1.28617 to 1.27266, saving model to model.h5
# Epoch 25/100
#  - 26s - loss: 1.0499 - val_loss: 1.2597
#
# Epoch 00025: val_loss improved from 1.27266 to 1.25966, saving model to model.h5
# Epoch 26/100
#  - 25s - loss: 1.0219 - val_loss: 1.2395
#
# Epoch 00026: val_loss improved from 1.25966 to 1.23948, saving model to model.h5
# Epoch 27/100
#  - 25s - loss: 0.9946 - val_loss: 1.2244
#
# Epoch 00027: val_loss improved from 1.23948 to 1.22435, saving model to model.h5
# Epoch 28/100
#  - 26s - loss: 0.9679 - val_loss: 1.2218
#
# Epoch 00028: val_loss improved from 1.22435 to 1.22184, saving model to model.h5
# Epoch 29/100
#  - 25s - loss: 0.9438 - val_loss: 1.2037
#
# Epoch 00029: val_loss improved from 1.22184 to 1.20374, saving model to model.h5
# Epoch 30/100
#  - 25s - loss: 0.9123 - val_loss: 1.1827
#
# Epoch 00030: val_loss improved from 1.20374 to 1.18271, saving model to model.h5
# Epoch 31/100
#  - 25s - loss: 0.8857 - val_loss: 1.1797
#
# Epoch 00031: val_loss improved from 1.18271 to 1.17970, saving model to model.h5
# Epoch 32/100
#  - 25s - loss: 0.8586 - val_loss: 1.1578
#
# Epoch 00032: val_loss improved from 1.17970 to 1.15781, saving model to model.h5
# Epoch 33/100
#  - 25s - loss: 0.8287 - val_loss: 1.1412
#
# Epoch 00033: val_loss improved from 1.15781 to 1.14121, saving model to model.h5
# Epoch 34/100
#  - 25s - loss: 0.7953 - val_loss: 1.1355
#
# Epoch 00034: val_loss improved from 1.14121 to 1.13548, saving model to model.h5
# Epoch 35/100
#  - 25s - loss: 0.7684 - val_loss: 1.1228
#
# Epoch 00035: val_loss improved from 1.13548 to 1.12276, saving model to model.h5
# Epoch 36/100
#  - 26s - loss: 0.7425 - val_loss: 1.1109
#
# Epoch 00036: val_loss improved from 1.12276 to 1.11091, saving model to model.h5
# Epoch 37/100
#  - 25s - loss: 0.7202 - val_loss: 1.0966
#
# Epoch 00037: val_loss improved from 1.11091 to 1.09662, saving model to model.h5
# Epoch 38/100
#  - 25s - loss: 0.6962 - val_loss: 1.0817
#
# Epoch 00038: val_loss improved from 1.09662 to 1.08174, saving model to model.h5
# Epoch 39/100
#  - 25s - loss: 0.6697 - val_loss: 1.0745
#
# Epoch 00039: val_loss improved from 1.08174 to 1.07447, saving model to model.h5
# Epoch 40/100
#  - 25s - loss: 0.6428 - val_loss: 1.0647
#
# Epoch 00040: val_loss improved from 1.07447 to 1.06468, saving model to model.h5
# Epoch 41/100
#  - 25s - loss: 0.6189 - val_loss: 1.0569
#
# Epoch 00041: val_loss improved from 1.06468 to 1.05691, saving model to model.h5
# Epoch 42/100
#  - 25s - loss: 0.5978 - val_loss: 1.0524
#
# Epoch 00042: val_loss improved from 1.05691 to 1.05240, saving model to model.h5
# Epoch 43/100
#  - 25s - loss: 0.5775 - val_loss: 1.0456
#
# Epoch 00043: val_loss improved from 1.05240 to 1.04562, saving model to model.h5
# Epoch 44/100
#  - 25s - loss: 0.5547 - val_loss: 1.0356
#
# Epoch 00044: val_loss improved from 1.04562 to 1.03560, saving model to model.h5
# Epoch 45/100
#  - 25s - loss: 0.5305 - val_loss: 1.0266
#
# Epoch 00045: val_loss improved from 1.03560 to 1.02658, saving model to model.h5
# Epoch 46/100
#  - 25s - loss: 0.5113 - val_loss: 1.0267
#
# Epoch 00046: val_loss did not improve from 1.02658
# Epoch 47/100
#  - 25s - loss: 0.4931 - val_loss: 1.0199
#
# Epoch 00047: val_loss improved from 1.02658 to 1.01990, saving model to model.h5
# Epoch 48/100
#  - 25s - loss: 0.4754 - val_loss: 1.0195
#
# Epoch 00048: val_loss improved from 1.01990 to 1.01948, saving model to model.h5
# Epoch 49/100
#  - 25s - loss: 0.4578 - val_loss: 1.0121
#
# Epoch 00049: val_loss improved from 1.01948 to 1.01213, saving model to model.h5
# Epoch 50/100
#  - 25s - loss: 0.4394 - val_loss: 1.0060
#
# Epoch 00050: val_loss improved from 1.01213 to 1.00598, saving model to model.h5
# Epoch 51/100
#  - 26s - loss: 0.4227 - val_loss: 1.0031
#
# Epoch 00051: val_loss improved from 1.00598 to 1.00311, saving model to model.h5
# Epoch 52/100
#  - 25s - loss: 0.4104 - val_loss: 0.9974
#
# Epoch 00052: val_loss improved from 1.00311 to 0.99744, saving model to model.h5
# Epoch 53/100
#  - 25s - loss: 0.3917 - val_loss: 0.9918
#
# Epoch 00053: val_loss improved from 0.99744 to 0.99180, saving model to model.h5
# Epoch 54/100
#  - 25s - loss: 0.3750 - val_loss: 0.9897
#
# Epoch 00054: val_loss improved from 0.99180 to 0.98973, saving model to model.h5
# Epoch 55/100
#  - 25s - loss: 0.3615 - val_loss: 0.9876
#
# Epoch 00055: val_loss improved from 0.98973 to 0.98758, saving model to model.h5
# Epoch 56/100
#  - 25s - loss: 0.3465 - val_loss: 0.9835
#
# Epoch 00056: val_loss improved from 0.98758 to 0.98352, saving model to model.h5
# Epoch 57/100
#  - 25s - loss: 0.3293 - val_loss: 0.9798
#
# Epoch 00057: val_loss improved from 0.98352 to 0.97981, saving model to model.h5
# Epoch 58/100
#  - 25s - loss: 0.3176 - val_loss: 0.9810
#
# Epoch 00058: val_loss did not improve from 0.97981
# Epoch 59/100
#  - 25s - loss: 0.3075 - val_loss: 0.9792
#
# Epoch 00059: val_loss improved from 0.97981 to 0.97923, saving model to model.h5
# Epoch 60/100
#  - 26s - loss: 0.2989 - val_loss: 0.9747
#
# Epoch 00060: val_loss improved from 0.97923 to 0.97471, saving model to model.h5
# Epoch 61/100
#  - 25s - loss: 0.2866 - val_loss: 0.9763
#
# Epoch 00061: val_loss did not improve from 0.97471
# Epoch 62/100
#  - 25s - loss: 0.2746 - val_loss: 0.9741
#
# Epoch 00062: val_loss improved from 0.97471 to 0.97408, saving model to model.h5
# Epoch 63/100
#  - 25s - loss: 0.2635 - val_loss: 0.9715
#
# Epoch 00063: val_loss improved from 0.97408 to 0.97146, saving model to model.h5
# Epoch 64/100
#  - 25s - loss: 0.2567 - val_loss: 0.9758
#
# Epoch 00064: val_loss did not improve from 0.97146
# Epoch 65/100
#  - 25s - loss: 0.2476 - val_loss: 0.9745
#
# Epoch 00065: val_loss did not improve from 0.97146
# Epoch 66/100
#  - 25s - loss: 0.2379 - val_loss: 0.9698
#
# Epoch 00066: val_loss improved from 0.97146 to 0.96982, saving model to model.h5
# Epoch 67/100
#  - 25s - loss: 0.2275 - val_loss: 0.9664
#
# Epoch 00067: val_loss improved from 0.96982 to 0.96642, saving model to model.h5
# Epoch 68/100
#  - 25s - loss: 0.2192 - val_loss: 0.9687
#
# Epoch 00068: val_loss did not improve from 0.96642
# Epoch 69/100
#  - 25s - loss: 0.2119 - val_loss: 0.9643
#
# Epoch 00069: val_loss improved from 0.96642 to 0.96433, saving model to model.h5
# Epoch 70/100
#  - 25s - loss: 0.2046 - val_loss: 0.9704
#
# Epoch 00070: val_loss did not improve from 0.96433
# Epoch 71/100
#  - 25s - loss: 0.1967 - val_loss: 0.9715
#
# Epoch 00071: val_loss did not improve from 0.96433
# Epoch 72/100
#  - 25s - loss: 0.1915 - val_loss: 0.9674
#
# Epoch 00072: val_loss did not improve from 0.96433
# Epoch 73/100
#  - 25s - loss: 0.1862 - val_loss: 0.9730
#
# Epoch 00073: val_loss did not improve from 0.96433
# Epoch 74/100
#  - 25s - loss: 0.1782 - val_loss: 0.9718
#
# Epoch 00074: val_loss did not improve from 0.96433
# Epoch 75/100
#  - 25s - loss: 0.1704 - val_loss: 0.9722
#
# Epoch 00075: val_loss did not improve from 0.96433
# Epoch 76/100
#  - 25s - loss: 0.1664 - val_loss: 0.9706
#
# Epoch 00076: val_loss did not improve from 0.96433
# Epoch 77/100
#  - 25s - loss: 0.1623 - val_loss: 0.9748
#
# Epoch 00077: val_loss did not improve from 0.96433
# Epoch 78/100
#  - 26s - loss: 0.1689 - val_loss: 0.9769
#
# Epoch 00078: val_loss did not improve from 0.96433
# Epoch 79/100
#  - 26s - loss: 0.1562 - val_loss: 0.9722
#
# Epoch 00079: val_loss did not improve from 0.96433
# Epoch 80/100
#  - 26s - loss: 0.1439 - val_loss: 0.9753
#
# Epoch 00080: val_loss did not improve from 0.96433
# Epoch 81/100
#  - 26s - loss: 0.1352 - val_loss: 0.9791
#
# Epoch 00081: val_loss did not improve from 0.96433
# Epoch 82/100
#  - 25s - loss: 0.1323 - val_loss: 0.9821
#
# Epoch 00082: val_loss did not improve from 0.96433
# Epoch 83/100
#  - 25s - loss: 0.1298 - val_loss: 0.9826
#
# Epoch 00083: val_loss did not improve from 0.96433
# Epoch 84/100
#  - 26s - loss: 0.1268 - val_loss: 0.9839
#
# Epoch 00084: val_loss did not improve from 0.96433
# Epoch 85/100
#  - 26s - loss: 0.1226 - val_loss: 0.9750
#
# Epoch 00085: val_loss did not improve from 0.96433
# Epoch 86/100
#  - 29s - loss: 0.1194 - val_loss: 0.9859
#
# Epoch 00086: val_loss did not improve from 0.96433
# Epoch 87/100
#  - 26s - loss: 0.1139 - val_loss: 0.9839
#
# Epoch 00087: val_loss did not improve from 0.96433
# Epoch 88/100
#  - 26s - loss: 0.1086 - val_loss: 0.9842
#
# Epoch 00088: val_loss did not improve from 0.96433
# Epoch 89/100
#  - 25s - loss: 0.1039 - val_loss: 0.9903
#
# Epoch 00089: val_loss did not improve from 0.96433
# Epoch 90/100
#  - 26s - loss: 0.1016 - val_loss: 0.9931
#
# Epoch 00090: val_loss did not improve from 0.96433
# Epoch 91/100
#  - 25s - loss: 0.1006 - val_loss: 0.9902
#
# Epoch 00091: val_loss did not improve from 0.96433
# Epoch 92/100
#  - 25s - loss: 0.1032 - val_loss: 1.0006
#
# Epoch 00092: val_loss did not improve from 0.96433
# Epoch 93/100
#  - 25s - loss: 0.1003 - val_loss: 1.0023
#
# Epoch 00093: val_loss did not improve from 0.96433
# Epoch 94/100
#  - 25s - loss: 0.0959 - val_loss: 0.9955
#
# Epoch 00094: val_loss did not improve from 0.96433
# Epoch 95/100
#  - 26s - loss: 0.0929 - val_loss: 0.9996
#
# Epoch 00095: val_loss did not improve from 0.96433
# Epoch 96/100
#  - 26s - loss: 0.0894 - val_loss: 1.0082
#
# Epoch 00096: val_loss did not improve from 0.96433
# Epoch 97/100
#  - 25s - loss: 0.0869 - val_loss: 1.0081
#
# Epoch 00097: val_loss did not improve from 0.96433
# Epoch 98/100
#  - 25s - loss: 0.0849 - val_loss: 1.0125
#
# Epoch 00098: val_loss did not improve from 0.96433
# Epoch 99/100
#  - 25s - loss: 0.0866 - val_loss: 1.0097
#
# Epoch 00099: val_loss did not improve from 0.96433
# Epoch 100/100
#  - 26s - loss: 0.0841 - val_loss: 1.0152
#
# Epoch 00100: val_loss did not improve from 0.96433

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ##### Loading Data

# %%
def load_clean_sentences(filename):
  return load(open(filename, 'rb'))

# %%
dataset = load_clean_sentences('english-bangla-both.pkl')
train = load_clean_sentences('english-bangla-train.pkl')
test = load_clean_sentences('english-bangla-test.pkl')

# %% [markdown]
# ##### Tokenizer and Max Length

# %%
def create_tokenizer(lines):
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(lines)
  return tokenizer

# %%
# max sentence length
def max_length(lines):
  return max(len(line.split()) for line in lines)

# %%
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])

# prepare bangla tokenizer
bang_tokenizer = create_tokenizer(dataset[:, 1])
bang_vocab_size = len(bang_tokenizer.word_index) + 1
bang_length = max_length(dataset[:, 1])

# %% [markdown]
# ##### Sequence Encoding

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
  # integer encode sequences
  X = tokenizer.texts_to_sequences(lines)
  # pad sequences with 0 values
  X = pad_sequences(X, maxlen=length, padding= 'post')
  return X

# %%
# prepare data
trainX = encode_sequences(bang_tokenizer, bang_length, train[:, 1])
testX = encode_sequences(bang_tokenizer, bang_length, test[:, 1])

# %% [markdown]
# ##### Generate Sequence

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
  for word, index in tokenizer.word_index.items():
    if index==integer:
      return word
  return None


# generate target given source sequence
def predict_sequence(model, tokenizer, source):
  prediction = model.predict(source, verbose=0)[0]
  integers = [argmax(vector) for vector in prediction]
  target = list()
  for i in integers:
    word = word_for_id(i, tokenizer)
    if word is None:
      break
    target.append(word)
  return ' '.join(target)


# evaluate the skill of the model
def evaluate_model(model, sources, raw_dataset):
  actual, predicted = list(), list()
  for i, source in enumerate(sources):
    # translate encoded source text
    source = source.reshape((1, source.shape[0]))
    translation = predict_sequence(model, eng_tokenizer, source)
    raw_target, raw_src = raw_dataset[i,:2]
    if i < 10:
      print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
    actual.append(raw_target.split())
    predicted.append(translation.split())

  # calculate BLEU score
  print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
  print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0))) 
  print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
  print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
# load model
model = load_model('model.h5')

# test on some training sequences
print('train')
evaluate_model(model, trainX, train)

# test on some test sequences
print('test')
evaluate_model(model, testX, test)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# train
# src=[ও হাঁটে], target=[She walks], predicted=[she walks]
# src=[অারো অাস্তে হাঁটো], target=[Walk more slowly], predicted=[walk more slowly]
# src=[আপনি পিয়ানো বাজাতে পারেন], target=[Can you play the piano], predicted=[can you the the piano]
# src=[বাইরে গিয়ে অপেক্ষা করো], target=[Go wait outside], predicted=[go wait outside]
# src=[আমি এটা সামলে নিতে পারি], target=[I can manage it], predicted=[i can manage it]
# src=[এখানে দাঁড়াও], target=[Stay here], predicted=[stay here]
# src=[ওখানে দেখা হবে], target=[See you there], predicted=[see you there]
# src=[তিনি ফরাসিতে কথা বলতে পারেন], target=[She can speak French], predicted=[she can speak french]
# src=[টমকে মার], target=[Hit Tom], predicted=[hit tom]
# src=[সেটা কোন তলায়], target=[Which floor is it on], predicted=[what floor is it on]
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-1: 0.041064
# BLEU-2: 0.202643
# BLEU-3: 0.383742
# BLEU-4: 0.450159
# test
# src=[কে দৌড়ালেন], target=[Who ran], predicted=[who was]
# src=[আপনি ওখানে বসে আছেন কেন], target=[Why are you sitting there], predicted=[why are you sitting there]
# src=[ও নাচতে চায়], target=[She wants to dance], predicted=[he cant dance dance]
# src=[সময় শেষ], target=[Time is up], predicted=[whats is]
# src=[আমি নিশ্চিত আমার বাবামা আমাকে একলা যেতে দেবে না], target=[Im sure my parents wont let me go by myself], predicted=[i dont want to i but i the of of]
# src=[টম চেঁচাতে আরম্ভ করলো], target=[Tom started to scream], predicted=[tom began to shout]
# src=[বাজারটা ডাক্তারখানার পাশে], target=[The market is next to the pharmacy], predicted=[is is a doctor]
# src=[অনুগ্রহ করে আপনার পাসপোর্টটি দেখাবেন], target=[Show me your passport please], predicted=[you you show your your passport please]
# src=[আমি যখন গিলতে যাই তখন আমার গলা ব্যাথা করে], target=[My throat hurts when I swallow], predicted=[i thought i when when when when i was the be]
# src=[আমরা কি প্রস্তুত আছি], target=[Are we prepared], predicted=[are we sick]
# BLEU-1: 0.038147
# BLEU-2: 0.195313
# BLEU-3: 0.375352
# BLEU-4: 0.441942

# %% [markdown]
# ## How to get more accurate translated English Language

# %% [markdown]
# ##### Note: How to increasse more accuracy/ reduce loss
#
# 1) Take more and more data for training
#
# 2) Hyperparameter tuning
#
# 3) Add more Layer and check different parameter
